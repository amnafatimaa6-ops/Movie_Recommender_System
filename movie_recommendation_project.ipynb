# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/content/movies_metadata.csv", low_memory=False, on_bad_lines='skip')

# %%
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
df = df.drop_duplicates().reset_index(drop = True)

# %%
#selects only the relevant columns from the original DataFrame.
#it trims the dataset down to key movie features (metadata + popularity metrics)to make analysis cleaner, faster, and more focused.
df = df[['title','overview','genres','tagline','vote_average','popularity']]
df.head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                              tagline  vote_average popularity
# ...

# %%
#filling nan in relevant cols
df = df.dropna(subset=['title'])
df['overview'] = df['overview'].fillna('')
df['tagline'] = df['tagline'].fillna('')
df.isnull().sum()
# Out:
# title           0
# overview        0
# genres          0
# tagline         0
# vote_average    0
# popularity      0
# dtype: int64

# %%
#convert 'genres' from stringified list of dicts to a single string of genre names
import ast
df['genres'] = df['genres'].apply(lambda x :''.join([i['name']for i in ast.literal_eval(x)]))

# %%
df.head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview                  genres  \
# 0  Led by Woody, Andy's toys live happily in his ...   AnimationComedyFamily
# 1  When siblings Judy and Peter discover an encha...  AdventureFantasyFamily
# 2  A family wedding reignites the ancient feud be...           RomanceComedy
# 3  Cheated on, mistreated and stepped on, the wom...      ComedyDramaRomance
# 4  Just when George Banks has recovered from his ...                  Comedy
#
#                                              tagline  vote_average popularity
# 0                                                              7.7  21.946943
# 1          Roll the dice and unleash the excitement!           6.9  17.015539
# ...

# %%
#create a 'tags' column by combining overview, genres, and tagline into a single text string
df['tags']=df['overview']+''+df['genres']+''+df['tagline']
df.head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview                  genres  \
# 0  Led by Woody, Andy's toys live happily in his ...   AnimationComedyFamily
# 1  When siblings Judy and Peter discover an encha...  AdventureFantasyFamily
# 2  A family wedding reignites the ancient feud be...           RomanceComedy
# 3  Cheated on, mistreated and stepped on, the wom...      ComedyDramaRomance
# 4  Just when George Banks has recovered from his ...                  Comedy
#
#                                              tagline  vote_average popularity  \
# 0                                                              7.7  21.946943
# 1          Roll the dice and unleash the excitement!           6.9  17.015539
# ...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re

# %%
#download necessary NLTK resources
nltk.download('stopwords') #common words like 'the', 'is', 'and' that usually get removed
nltk.download('wordnet')   #dictionary for lemmatization
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
#prepare tools for text preprocessing
stop_words = set(stopwords.words('english')) #set of words to ignore
lemmatizer = WordNetLemmatizer()             #tool to reduce words to their base form

# %%
def process_text(text):
    text = str(text).lower()  #converts to lowercase
    text = re.sub(r'[^a-zA-Z\s]', '', text)  #remove punctuation
    words = text.split()
    words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]  # remove stopwords & lemmatize
    return " ".join(words)  #combine cleaned words back into a single string

# %%
import ast

def parse_genres(x):
    try:
        #if x is already a list/dict, just use it
        if isinstance(x, list):
            return ' '.join([i['name'] for i in x])
        #if x is a string representing list/dict
        elif isinstance(x, str):
            data = ast.literal_eval(x)
            return ' '.join([i['name'] for i in data])
        else:
            return ''  #empty string for malformed or missing data
    except:
        return ''  #fallback for any error

df['genres'] = df['genres'].apply(parse_genres)

df['tags'] = df['overview'].fillna('') + ' ' + df['genres'].fillna('') + ' ' + df['tagline'].fillna('')
df['tags'] = df['tags'].apply(process_text)

# %%
#reset index & create indices map ---
df = df.reset_index(drop=True)
indices = pd.Series(df.index, index=df['title']).drop_duplicates()

# %%
#import the TfidfVectorizer class from scikit-learn
from sklearn.feature_extraction.text import TfidfVectorizer
#keeps only the 5000 most significant words/bigrams to avoid a massive, sparse matrix
#considers both single words and pairs of consecutive words to capture context better
#moves common filler words so only meaningful words affect the model
tfidf = TfidfVectorizer(max_features=5000, ngram_range=(1,2), stop_words='english')
tfidf_matrix = tfidf.fit_transform(df['tags']) #for machine learning models or similarity computations

# %%
from sklearn.metrics.pairwise import cosine_similarity

#recommender function ---
def recommend(title, n=10):
#check if the movie exists in your dataset
    if title not in indices:
        return ['Movie not found']
    #get the index of the movie in your DataFrame
    idx = indices[title]
    #compute cosine similarity between this movie and all movies
    sim_scores = cosine_similarity(tfidf_matrix[idx], tfidf_matrix).flatten()
    #sort similarity scores in descending order, skip the first one (itself)
    similar_idx = sim_scores.argsort()[::-1][1:n+1]
    #return the titles of the top-n similar movies
    return df['title'].iloc[similar_idx].values

# %%
#Example usage ---
print(recommend('Toy Story'))
# Out:
# ['Toy Story 2' 'Toy Reanimator'
#  'Silent Night, Deadly Night 5: The Toy Maker' 'Hawaiian Vacation'
#  'How the Toys Saved Christmas' "Don't Give a Damn" 'Toy Story of Terror!'
#  'Motel Cactus' 'Dollman vs. Demonic Toys'
#  'The Last Chance: Diary of Comedians']

# %%
print(recommend('The Dark Knight Rises'))
# Out:
# ['Batman Forever' 'The Dark Knight' 'Slow Burn' 'Batman Returns'
#  'Batman Unmasked: The Psychology of the Dark Knight'
#  'Batman: Mask of the Phantasm' 'Accused' 'Night Falls on Manhattan'
#  'LEGO DC Comics Super Heroes: Batman: Be-Leaguered' 'Rage of Angels']

# %%
# !pip install -q sentence-transformers
from sentence_transformers import SentenceTransformer
import numpy as np

#load a pre-trained model (small & fast for now)
model = SentenceTransformer('all-MiniLM-L6-v2')

#encode all movie tags into embeddings
embeddings = model.encode(df['tags'].tolist(), show_progress_bar=True)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# ...

# %%
def semantic_recommend(title, n=10):
    if title not in indices:
        return ['Movie not found']

    idx = indices[title]
    movie_emb = embeddings[idx]

    #compute cosine similarity with all movies
    sim_scores = np.dot(embeddings, movie_emb) / (np.linalg.norm(embeddings, axis=1) * np.linalg.norm(movie_emb))

    #get top n similar movies (excluding itself)
    similar_idx = sim_scores.argsort()[::-1][1:n+1]
    return df['title'].iloc[similar_idx].values

# %%
print(semantic_recommend('Toy Story'))
print(semantic_recommend('The Dark Knight Rises'))
# Out:
# ['Toy Story 3' 'Toy Story 2' 'Toy Reanimator' 'Firestarter'
#  'Toy Story of Terror!' 'Hollywood Ending' "Andy Hardy's Blonde Trouble"
#  'Sunspring' '1 Night' 'Hanging Garden']
# ['The Dark Knight' 'Batman Forever'
#  'Batman: The Dark Knight Returns, Part 1' 'Batman Returns'
#  'Batman: Mystery of the Batwoman' 'Batman Begins'
#  'Batman Beyond: Return of the Joker' 'Batman Beyond: The Movie' 'Batman'
#  'Batman v Superman: Dawn of Justice']

# %%
def recommend_by_genre_from_tags(user_genre, n=10):
    user_genre = user_genre.lower().strip()

    #filter movies whose 'tags' contain the genre keyword
    genre_filtered_df = df[df['tags'].str.contains(user_genre, case=False, na=False)]
# - case=False → ignore uppercase/lowercase
    # - na=False → skip rows where 'tags' is missing
    if genre_filtered_df.empty:
        return ['Genre not found']


    return genre_filtered_df['title'].head(n).values

# %%
print(recommend_by_genre_from_tags('Action'))
# Out:
# ['Sudden Death' 'Mortal Kombat' 'Guardian Angel' 'Georgia'
#  'Heidi Fleiss: Hollywood Madam' 'Taxi Driver'
#  'Die Hard: With a Vengeance' 'Something to Talk About' 'Love Affair'
#  "Mary Shelley's Frankenstein"]

# %%
print(recommend_by_genre_from_tags('Animation'))
# Out:
# ['The Secret Adventures of Tom Thumb' 'Frank and Ollie'
#  'The Nightmare Before Christmas' 'Faust' 'Young Frankenstein'
#  'Re-Animator' 'Fantasia 2000' 'Time Masters' 'Gandahar' 'Galaxina']

# %%
print(recommend_by_genre_from_tags('Romance'))
# Out:
# ['The Crossing Guard' 'Angels and Insects' 'If Lucy Fell'
#  'Up Close & Personal' 'Total Eclipse' 'Before Sunrise' 'Don Juan DeMarco'
#  'I Love Trouble' 'Clean Slate' 'Much Ado About Nothing']

# %% [markdown]
# #i switch from TF-IDF(Term Frequency, Inverse Document Frequency) to SentenceTransformer embeddings because:
# #TF-IDF only captures word overlap, missing semantic meaning
# #Transformers capture meaning/context of the tags
# #Cosine similarity on embeddings gives smarter, context-aware recommendations
